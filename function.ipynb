# %% [markdown]
# <a href="https://colab.research.google.com/github/namanbajpai0007/SD_Naman0149/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test():
  pass

# %%
def test1():
  print("this is my first program")

# %%
test1()
# Out:
# this is my first program

# %%
test1() + "naman"
# Out:
# this is my first program
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/1704524735.py in <cell line: 0>()
# ----> 1 test1() + "naman"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my first return"

# %%
test2()

# %%
test2()+"naman"
# Out:
# 'this is my first returnnaman'

# %%
def test3() :

    return "naman",23,345.56,[1,2,3,4,4]

# %%
test3()
# Out:
# ('naman', 23, 345.56, [1, 2, 3, 4, 4])

# %%
a,b,c,d = test3( )

# %%
a
# Out:
# 'naman'

# %%
type(test3)

# %%
b
# Out:
# 23

# %%
c

# %%
d
# Out:
# [1, 2, 3, 4, 4]

# %%
a,b

# %%
def add():
  a=5+6/7
  return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d=a+b/c
  return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
test5(3,5,9)
# Out:
# 3.5555555555555554

# %%
def test6(a,b):
  return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("sudh","kumar")
# Out:
# 'sudhkumar'

# %%
def test11(*args):
  return args

# %%
def test13(*args,a) :
  return args , a

# %%
test13(1,2,3,4, a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def tesr14(c,d,a = 23 , b=1):
  return a,b,c,d

# %%
test14(3,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_658/3844969914.py in <cell line: 0>()
# ----> 1 test14(3,4)
#
# NameError: name 'test14' is not defined

# %%
def test15(**kwargs):
  return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def add(a,b):
  return a+b
  def sub(a,b):
    return a-b

# %%
def calc(a,b,p):
  if (p=="+"):

    print(a+b)
  elif(p=="-"):
    print(a-b)
  elif(p=="*"):
    print(a*b)
  elif(p=="/"):
    print(a/b)
  return "done"
n1=int(input("enter num1"))
n2=int(input("enter num2"))
op=(input("enter opt"))
calc(n1,n2,op)
# Out:
# enter num15
# enter num24
# enter opt+,-,*,/
# 'done'
