# %% [markdown]
# <a href="https://colab.research.google.com/github/namanbajpai0007/SD_Naman0149/blob/main/LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l =[1,345,45,"sudh",True,5+7j,345.456]

# %%
l[5].real
# Out:
# 5.0

# %%
l[0:5:4]
# Out:
# [1, True]

# %%
l[-1]
# Out:
# 345.456

# %%
l[6]
# Out:
# 345.456

# %%
l[-5]
# Out:
# 45

# %%
l[-3]
# Out:
# True

# %%
l[+1:+6:+2]
# Out:
# [345, 'sudh', (5+7j)]

# %%
l[-7:-6]
# Out:
# [1]

# %%
l[-6:-8]
# Out:
# []

# %%
l.append(55)

# %%
s ="asdfghjkl"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3438/1912199427.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['a',
#  's',
#  'd',
#  'f',
#  'g',
#  'h',
#  'j',
#  'k',
#  'l',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55]

# %%
l1 =[1,22,333,4444,55555,]

# %%
l1.append(666666)

# %%
l[3][0:2]
# Out:
# 'su'

# %%
str(l[4])[0:4]
# Out:
# 'True'

# %%
l.insert(11,22)

# %%
l[11]
# Out:
# 22

# %%
z = "10"
v = int(x)
print(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3438/684090871.py in <cell line: 0>()
#       1 z = "10"
# ----> 2 v = int(x)
#       3 print(v)
#
# NameError: name 'x' is not defined
