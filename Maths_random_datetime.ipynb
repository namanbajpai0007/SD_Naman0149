# %% [markdown]
# <a href="https://colab.research.google.com/github/namanbajpai0007/SD_Naman0149/blob/main/Maths_random_datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

num=25
print(math.sqrt(num))
# Out:
# 5.0

# %%
print(math.pow(2,5))
# Out:
# 32.0

# %%
print(math.factorial(7))
# Out:
# 5040

# %%
print(math.ceil(4.2))
# Out:
# 5

# %%
print(math.floor(4.9))
# Out:
# 4

# %%
print(abs(-90))
# Out:
# 90

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.cos(math.radians(45)))
# Out:
# 0.7071067811865476

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
import random

fruits = ["apple","banana","mango"]
print(random.choice(fruits))
# Out:
# mango

# %%
import random
numbers = [1,2,3,4,5,6]
random.shuffle(numbers)
print(numbers)
# Out:
# [6, 4, 3, 1, 5, 2]

# %%
import random
print(random.uniform(1,10))
# Out:
# 5.803340300757492

# %%
import random

# %%
import random
otp = random.randint(10000,99999)
print("OTP=",otp)
# Out:
# OTP= 86868

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:25:54.675329

# %%
print(datetime.date.today())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().time())
# Out:
# 06:29:43.140200

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().hour)
# Out:
# 6

# %%
print(datetime.datetime.now().minute)
# Out:
# 35

# %%
print(datetime.datetime.now().second)
# Out:
# 6

# %%
print(datetime.datetime.now().microsecond)
# Out:
# 309822

# %%
#custom

d=datetime.date(2026,7,19)

print(d)
# Out:
# 2026-07-19

# %%
import datetime

t=datetime.time(10,30,45)

print(t)
# Out:
# 10:30:45

# %%
date1 = datetime.date(2026,7,19)
date2 = datetime.date(2026,8,19)

print(date2 - date1)
# Out:
# 31 days, 0:00:00

# %%
import datetime
today=datetime.datetime.now()
print(today.strftime("%A"))
# Out:
# Monday

# %%
import datetime
today=datetime.datetime.now()
print(today.strftime("%B"))
# Out:
# July

# %%
import time
from IPython.display import clear_output
from datetime import datetime

while True:
  clear_output(wait=True)

  current_time = datetime.now().strftime("%I:%M:%S %p")

  print("    DIGITAL  CLOCK")
  print(current_time)

  time.sleep(1)
# Out:
#     DIGITAL  CLOCK
# 09:07:08 AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8379/1088800428.py in <cell line: 0>()
#      11   print(current_time)
#      12
# ---> 13   time.sleep(1)
#
# KeyboardInterrupt:

# %%
import time
from IPython.display import clear_output
from datetime import datetime

from pytz import timezone
india_time =timezone("Asia/Kolkata")

while True:
  clear_output(wait=True)

  current_time = datetime.now().strftime("%I:%M:%S %p")

  print("    DIGITAL  CLOCK")
  print(current_time)

  time.sleep(1)
# Out:
#     DIGITAL  CLOCK
# 09:20:15 AM

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import ZoneInfo

while True:
  clear_output(wait=True)

  ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))

  print("   Digital Clock")
  print("Date :",ist_time.strftime("%d-%m-%Y"))
  print("Time :",ist_time.strftime("%I:%M:%S %p"))
  print("Zone :","Indian Standard Time (IST")
  print("Day :",ist_time.strftime("%A"))

  time.sleep(1)
