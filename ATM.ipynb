# %% [markdown]
# <a href="https://colab.research.google.com/github/namanbajpai0007/SD_Naman0149/blob/main/ATM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
card=int(input("enter the card number"))
pin=int(input("enter the pin number"))
servics1=input("withdrawl")
service2=input("check balance")
service3=input("change pin")

services=input("choose service")
amount=int(input("enter the amount"))
# Out:
# enter the card number321123
# enter the pin number4545
# withdrawlyes
# check balanceno
# change pinno
# choose service1
# enter the amount50000
